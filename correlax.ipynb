# %%
import pandas as pd
import correlax as cx

df = pd.read_csv('train.csv')

c = cx.Correlax(df)
c.corr
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.011156 -0.011949    -0.010601 -0.033226
# MSSubClass     0.011156    1.000000  0.286937    -0.386347 -0.139781
# MSZoning      -0.011949    0.286937  1.000000    -0.248800 -0.161640
# LotFrontage   -0.010601   -0.386347 -0.248800     1.000000  0.426095
# LotArea       -0.033226   -0.139781 -0.161640     0.426095  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.021172   -0.013585  0.022231     0.011200  0.001205
# YrSold         0.000712   -0.021407 -0.010621     0.007450 -0.014261
# SaleType      -0.016932    0.012874  0.058948     0.006370 -0.013882
# SaleCondition -0.017712   -0.015047  0.068705     0.072517  0.000199
# SalePrice     -0.021917   -0.084284 -0.116047     0.351799  0.263843
#
#                  Street     Alley  LotShape  LandContour  Utilities  ...  \
# ...

# %%
c.sort_by('SalePrice')
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
#                   ...
# GarageType     -0.255560
# ExterQual      -0.265015
# BsmtFinType1   -0.370971
# HeatingQC      -0.427649
# Foundation     -0.429678
# Name: SalePrice, Length: 81, dtype: float64

# %%
c.print_by('SalePrice', ascending=True)
# Out:
# Id : -0.021916719443430967
# MSSubClass : -0.08428413512659509
# MSZoning : -0.11604685049722235
# LotFrontage : 0.35179909657067737
# LotArea : 0.2638433538714051
# Street : -0.041035535500049486
# Alley : -0.09260744997351616
# LotShape : 0.2677593139178234
# LandContour : 0.0920092723220943
# Utilities : -0.01431429614724878
# LotConfig : 0.10910587139786662
# LandSlope : 0.0511522481794664
# Neighborhood : -0.14362114628100148
# Condition1 : -0.044820363948187655
# Condition2 : -0.004833384726957498
# BldgType : -0.11261070204133289
# HouseStyle : -0.18868775334778642
# OverallQual : 0.7909816005838053
# OverallCond : -0.07785589404867797
# YearBuilt : 0.5228973328794967
# YearRemodAdd : 0.5071009671113866
# RoofStyle : 0.15933238981812523
# RoofMatl : 0.03582044376773439
# Exterior1st : -0.12058564555627814
# Exterior2nd : -0.16471555110845498
# MasVnrType : 0.007122685656477801
# MasVnrArea : 0.47749304709571444
# ExterQual : -0.2650145945924491
# ...
